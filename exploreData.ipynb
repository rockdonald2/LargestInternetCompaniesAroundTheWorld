# %%
import pandas as pd
import numpy as np
import unicodecsv as csv

# %%
df = pd.read_csv('raw/largest2.csv')

# %%
df.drop(labels=["Unnamed: 0"], axis=1, inplace=True)

# %%
df
# Out:
#      Unnamed: 0  Rank            Company  Revenue ($B)  F.Y.  Employees  \
# 0             0     1             Amazon        386.06  2020  1298000.0
# 1             1     2           Alphabet        182.53  2020   135301.0
# 2             2     3             JD.com        114.97  2020   310000.0
# 3             3     4               Meta         85.96  2020    58604.0
# 4             4     5            Tencent         74.31  2020    85858.0
# ..          ...   ...                ...           ...   ...        ...
# 96           96    96           Flexport          1.27  2020     2000.0
# 97           97    97            LogMeIn          1.26  2019     3974.0
# 98           98    98         Craigslist          1.00  2018     1000.0
# 99           99    99               Grab          1.00  2018     6000.0
# 100         100   100  Ultimate Software          1.00  2018     5000.0
#
#      Market cap. ($B)     Headquarters  Founded                     Industry  \
# 0             1668.00          Seattle     1994                    Ecommerce
# 1             1524.00    Mountain View     1998                     Internet
# 2              115.96          Beijing     1998                    Ecommerce
# 3              842.49       Menlo Park     2004                 Social Media
# 4              763.11         Shenzhen     1998                     Internet
# ..                ...              ...      ...                          ...
# 96                NaN    San Francisco     2013  Software freight forwarding
# 97               4.21           Boston     2003                     Software
# 98                NaN    San Francisco     1995                  Classifieds
# 99                NaN        Singapore     2012               Transportation
# 100               NaN  Weston, Florida     1993                     Software
#
#      coord_lan   coord_lat
# 0    47.622455 -122.339474
# 1    35.752374  -81.700565
# 2    39.904211  116.407395
# 3    37.485073 -122.148282
# 4    22.538740  113.950995
# ..         ...         ...
# 96   37.786529 -122.405385
# 97   42.349005  -71.048229
# 98   37.790032 -122.404488
# 99   39.330348  -76.609577
# 100  26.096513  -80.381287
#
# [101 rows x 12 columns]

# %%
df.to_csv("normalized/normalized.csv", index=False)

# %%
df = pd.read_csv('raw/largest_internet_company_coordinates.csv')

# %%
df.to_csv("normalized/normalized.csv", index=False)

# %%
import geocoder

# %%
g = geocoder.arcgis('City of Industry')
g.json
# Out:
# {'address': 'City of Industry, Texas',
#  'bbox': {'northeast': [30.171490000000073, -96.29907999999999],
#   'southwest': [29.771490000000075, -96.69908]},
#  'confidence': 1,
#  'lat': 29.971490000000074,
#  'lng': -96.49907999999999,
#  'ok': True,
#  'quality': 'Locality',
#  'raw': {'name': 'City of Industry, Texas',
#   'extent': {'xmin': -96.69908,
#    'ymin': 29.771490000000075,
#    'xmax': -96.29907999999999,
#    'ymax': 30.171490000000073},
#   'feature': {'geometry': {'x': -96.49907999999999, 'y': 29.971490000000074},
#    'attributes': {'Score': 100, 'Addr_Type': 'Locality'}}},
#  'score': 100,
#  'status': 'OK'}

# %%
df = pd.read_csv("raw/largest_co_coord_ind.csv")

# %%
df.rename(columns={'Revenue ($B)': 'Revenue', 'Market cap. ($B)': 'Market Capitalization'}, inplace=True)

# %%
df[df['Employees'].isna()]
# Out:
#     Rank    Company  Revenue  F.Y.  Employees  Market Capitalization  \
# 14    15    Rakuten    13.48  2020        NaN                  19.34
# 17    18    NetEase    11.29  2020        NaN                  74.61
# 23    24       Kwai     9.05  2020        NaN                 131.75
# 42    43      Kakao     3.71  2020        NaN                  46.02
# 77    77        B2W     1.86  2020        NaN                   6.90
# 84    84  J2 Global     1.49  2020        NaN                   5.43
# 90    90    Mail.Ru     1.33  2020        NaN                   5.17
#
#       Headquarters  Founded      Industry  coord_lat   coord_lon  \
# 14           Tokyo     1997     Ecommerce  35.646572  139.653244
# 17        Hangzhou     1997      Internet  30.274150  120.155150
# 23         Beijing     2011  Social Media  39.904211  116.407395
# 42       Jeju City     2010      Internet  33.499621  126.531188
# 77  Rio de Janeiro     2006     Ecommerce -22.906847  -43.172897
# 84    Los Angeles,     1995      Internet  34.052234 -118.243685
# 90          Moscow     1998      Internet  55.755826   37.617300
#
#          geoc_city        country      continent  industry_cat
# 14        Setagaya          Japan           Asia     Ecommerce
# 17        Hangzhou          China           Asia      Internet
# 23         Beijing          China           Asia  Social Media
# 42         Jeju-si    South Korea           Asia      Internet
# 77  Rio de Janeiro         Brazil  South America     Ecommerce
# 84     Los Angeles  United States  North America      Internet
# 90          Moscow         Russia         Europe      Internet

# %%
df.at[14, "Employees"] = 23841
df.at[17, "Employees"] = 28239
df.at[23, "Employees"] = 21499
df.at[42, "Employees"] = 10644
df.at[77, "Employees"] = 156
df.at[84, "Employees"] = 4700
df.at[90, "Employees"] = 8842

# %%
# df[df['geoc_city'] == 'Galaxis']['geoc_city'] = 'Singapore'
df.loc[df['geoc_city'] == 'Galaxis', 'geoc_city'] = 'Singapore'

# %%
df[df['Headquarters'] == 'Singapore']
# Out:
#     Rank      Company  Revenue  F.Y.  Employees  Market Capitalization  \
# 36    37  Sea Limited     4.38  2020    33800.0                 128.07
# 99    99         Grab     1.00  2018     6000.0                    NaN
#
#    Headquarters  Founded        Industry  coord_lat   coord_lon  geoc_city  \
# 36    Singapore     2009       Ecommerce   1.300041  103.788603  Singapore
# 99    Singapore     2012  Transportation   1.352083  103.819836  Singapore
#
#       country continent    industry_cat
# 36  Singapore      Asia       Ecommerce
# 99  Singapore      Asia  Transportation

# %%
df.to_csv('normalized/normalized.csv', index=False)
